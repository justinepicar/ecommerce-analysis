# %%
# Load the "autoreload" extension
#%load_ext autoreload

#reload extension
# %reload_ext autoreload

# always reload modules marked with "%aimport"
# %autoreload 2

#Import all the necessary packages for modules
import os
import sys

#add the 'python' directory as one where we can import modules
py_dir = os.path.join(os.getcwd(), 'python')
sys.path.append(py_dir)

# import my method from the source code
from python.get_info import plot_hists, plot_violin

# %%
#Import all necessary packages for visualization and transformation of the data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # PRE-PROCESSING

# %%
#upload training set and change dtypes for visitor_id and label to a categorical object
train = pd.read_csv('data/train_20170701_to_20170731', index_col=0, dtype={'visitor_id':'object', 'label':'object'})
train.head()
# Out:
#             visitor_id  day0_time_on_site_seconds  day1_time_on_site_seconds  \
# 0  3092487309701391768                      570.0                        NaN
# 1   780253600713375371                      705.0                        NaN
# 2   953713676730854570                      373.0                        NaN
# 3   238925310298938861                     1919.0                        NaN
# 4  1090774782213816251                     2405.0                        NaN
#
#    day2_time_on_site_seconds  day3_time_on_site_seconds  \
# 0                     1021.0                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    day4_6_time_on_site_seconds  w2_time_on_site_seconds  day0_hits  day1_hits  \
# 0                          NaN                    533.0       26.0        NaN
# 1                          NaN                   1181.0       58.0        NaN
# 2                          NaN                    736.0       42.0        NaN
# 3                         14.0                    691.0       74.0        NaN
# 4                          0.0                    454.0       33.0        NaN
#
#    day2_hits  ...  day3_sessions  day4_6_sessions  w2_sessions  \
# 0        6.0  ...            NaN              NaN          2.0
# 1        NaN  ...            NaN              NaN          1.0
# 2        NaN  ...            NaN              NaN          1.0
# 3        NaN  ...            NaN              1.0          2.0
# 4        NaN  ...            NaN              1.0          2.0
#
#    day0_session_quality  day1_session_quality  day2_session_quality  \
# 0                  60.0                   NaN                   3.0
# 1                  85.0                   NaN                   NaN
# 2                  76.0                   NaN                   NaN
# 3                  79.0                   NaN                   NaN
# 4                  87.0                   NaN                   NaN
#
#    day3_session_quality  day4_6_session_quality  w2_session_quality  label
# 0                   NaN                     NaN                 1.5      1
# 1                   NaN                     NaN                79.0      1
# 2                   NaN                     NaN                65.0      1
# 3                   NaN                     1.0                43.5      1
# 4                   NaN                     1.0                 3.0      1
#
# [5 rows x 38 columns]

# %%
train.label.value_counts()/len(train.label)
# Out:
# 0    0.951713
# 1    0.048287
# Name: label, dtype: float64

# %%
#create blank column to plot violin boxplot
train['all']=''

#plot violin boxplot
plot_violin(train, 'IQR of Training Data')

#remove blank column
train = train.iloc[:,:-1]

# %% [markdown]
# Looking at a preview of the data once again and at the percentage of customers who don't purchase (label 0) vs. customers who do purchase (label 1), we can see that customer's who make a purchase make up less than 5% of the dataset. In other words, the data is highly imbalanced and customers making a purchase is considered a rare event. The violin boxplot also shows that there are significant outliers in the data.
#
# We will perform each the following pre-processing techniques to mitigate any biases and inaccuracies in predicting customer propensity:
#
# - No Change (Control)
# - Log Transformation
# - Scaling (Standardization)
#
# We will be doing each technique separately to see which works best.

# %% [markdown]
# ### LOG-TRANSFORM

# %%
train_log = train.iloc[:,1:-1]
train_log = (train_log+1).transform(np.log)
#Negative Values Handling
#Note that the values are different
train_log = (train_log-train_log.min()+1).transform(np.log)
train_log.insert(0, 'visitor_id', train.visitor_id)
train_log['label'] = train['label']

# %% [markdown]
# Let's check to see what the data looks like now.

# %%
#create blank column to plot violin boxplot
train_log['all']=''

plot_violin(train_log, 'IQR of Training Data (Log-Transform)')

#remove blank column
train_log = train_log.iloc[:,:-1]

# %%
plot_hists(train_log, 'Log-Transform Distribution')

# %% [markdown]
# Based off both the violin boxplot and the histogram, we can see that most of the features have been transformed and even reducing any significantly large or small outliers. The data is still imbalanced, however.

# %% [markdown]
# ### SCALE THE DATA

# %% [markdown]
# #### STANDARDIZATION

# %%
scaler = StandardScaler()

#Create a new dataframe, whilst setting the index to 'visitor_id'
train_scale = train.set_index('visitor_id')

#Save the column names (using the `columns` attribute)
train_scale_columns = train_scale.iloc[:,:-1].columns

#Fit to scaler, except for labels
scaler.fit((train_scale.iloc[:,:-1]))

#Transform the data
scaled = scaler.transform(train_scale.iloc[:,:-1])

#Create a new dataframe using the column names
train_scaled = pd.DataFrame(scaled, columns=train_scale_columns)

#insert visitor_id and labels
train_scaled.insert(0, 'visitor_id', train.visitor_id)
train_scaled['label'] = train['label']

# %% [markdown]
# Let's confirm that the data has been normalized

# %%
train_scaled.describe().T[['mean', 'std']]
# Out:
#                                      mean       std
# day0_time_on_site_seconds    5.314037e-15  1.000130
# day1_time_on_site_seconds   -7.738056e-16  1.000179
# day2_time_on_site_seconds    1.440034e-15  1.000200
# day3_time_on_site_seconds    1.725406e-16  1.000198
# day4_6_time_on_site_seconds -1.300795e-15  1.000090
# w2_time_on_site_seconds      8.487496e-17  1.000037
# day0_hits                    4.182848e-15  1.000130
# day1_hits                   -5.540013e-16  1.000179
# day2_hits                   -4.715347e-16  1.000200
# day3_hits                    2.964103e-16  1.000198
# day4_6_hits                 -2.906313e-16  1.000090
# w2_hits                     -6.708131e-16  1.000037
# day0_pageViews              -5.813825e-15  1.000130
# day1_pageViews               4.386769e-16  1.000179
# day2_pageViews               1.710124e-15  1.000200
# day3_pageViews              -4.512802e-16  1.000198
# day4_6_pageViews             1.792303e-16  1.000090
# w2_pageViews                -3.254828e-16  1.000037
# day0_bounces                 1.294079e-15  1.000130
# day1_bounces                -1.708950e-17  1.000179
# day2_bounces                -7.833585e-16  1.000200
# day3_bounces                 6.442977e-16  1.000198
# day4_6_bounces               6.944774e-16  1.000090
# w2_bounces                   1.944927e-16  1.000037
# day0_sessions               -6.919929e-15  1.000130
# day1_sessions               -1.264663e-15  1.000179
# day2_sessions               -7.394546e-16  1.000200
# day3_sessions               -2.474982e-16  1.000198
# day4_6_sessions              8.600342e-16  1.000090
# w2_sessions                  1.694673e-16  1.000037
# day0_session_quality         1.318974e-14  1.000130
# day1_session_quality        -5.553891e-16  1.000179
# day2_session_quality         1.085879e-15  1.000200
# day3_session_quality        -2.346749e-15  1.000198
# day4_6_session_quality      -1.190500e-15  1.000090
# w2_session_quality           4.241348e-15  1.000037

# %%
#create blank column to plot violin boxplot
train_scaled['all']=''
plot_violin(train_scaled, 'IQR of Training Data (Standardized)')
#remove blank column
train_scaled = train_scaled.iloc[:,:-1]

# %%
plot_hists(train_scaled, 'Standardized Distribution')

# %% [markdown]
# It looks like scaling the data down did normalize the standard deviation close to 1 and the mean close to 0. However, based off of the histogram and violin plot, it looks like we are still dealing with very large outliers and a skewed distribution.

# %% [markdown]
# # MODELING

# %%
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from catboost import CatBoostClassifier
from catboost import CatBoostRegressor

# %% [markdown]
# We will be using the following models for our transformations:
#
# - CatBoost
# - Random Forest
#
# We will be combining these in a pipeline with the transformations we examined above.
# First, we need to split our data.

# %% [markdown]
# ### CATBOOST

# %%
#grab all features except for the target variable
X = train.iloc[:,:-1]
y = train[['label']]

#determine test_size for splitting the data
test_size = 0.3

#split data with random seed so we can replicate the results
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

# %%
#initialize the model
model = CatBoostClassifier(iterations=50)

# fit the model with the training data
model.fit(X_train, y_train, plot=False)
print('\n Model Trained')

# predict the target on the train dataset
y_pred_train = model.predict(X_train)
print(f'\nTarget on train data {y_pred_train}') 

# Accuracy Score on train dataset
accuracy_train = accuracy_score(y_train, y_pred_train)
print(f'\naccuracy_score on train dataset : {accuracy_train}')

# predict the target on the test dataset
y_pred_test = model.predict(X_test)
print(f'\nTarget on test data {predict}') 

# Accuracy Score on test dataset
accuracy_test = accuracy_score(y_test,y_pred_test)
print(f'\naccuracy_score on test dataset : {accuracy_test}')
# Out:
# Learning rate set to 0.495485
# 0:	learn: 0.0537017	total: 6.13ms	remaining: 300ms
# 1:	learn: 0.0223116	total: 12.7ms	remaining: 305ms
# 2:	learn: 0.0175498	total: 18.8ms	remaining: 295ms
# 3:	learn: 0.0173250	total: 24.6ms	remaining: 283ms
# 4:	learn: 0.0160093	total: 31.2ms	remaining: 281ms
# 5:	learn: 0.0159515	total: 37.2ms	remaining: 273ms
# 6:	learn: 0.0151107	total: 43.5ms	remaining: 267ms
# 7:	learn: 0.0146488	total: 49.4ms	remaining: 259ms
# 8:	learn: 0.0135428	total: 55.4ms	remaining: 252ms
# 9:	learn: 0.0120659	total: 62ms	remaining: 248ms
# 10:	learn: 0.0119140	total: 68.3ms	remaining: 242ms
# 11:	learn: 0.0111640	total: 75.2ms	remaining: 238ms
# 12:	learn: 0.0107415	total: 81.3ms	remaining: 231ms
# 13:	learn: 0.0107153	total: 86.8ms	remaining: 223ms
# 14:	learn: 0.0102324	total: 93.3ms	remaining: 218ms
# 15:	learn: 0.0092909	total: 99.8ms	remaining: 212ms
# 16:	learn: 0.0092185	total: 106ms	remaining: 205ms
# 17:	learn: 0.0088610	total: 112ms	remaining: 199ms
# 18:	learn: 0.0085341	total: 118ms	remaining: 192ms
# 19:	learn: 0.0079577	total: 124ms	remaining: 187ms
# 20:	learn: 0.0078333	total: 130ms	remaining: 180ms
# 21:	learn: 0.0073651	total: 136ms	remaining: 173ms
# 22:	learn: 0.0068370	total: 142ms	remaining: 167ms
# 23:	learn: 0.0064145	total: 148ms	remaining: 160ms
# 24:	learn: 0.0061995	total: 155ms	remaining: 155ms
# 25:	learn: 0.0061211	total: 161ms	remaining: 148ms
# 26:	learn: 0.0059200	total: 166ms	remaining: 141ms
# 27:	learn: 0.0056860	total: 173ms	remaining: 136ms
# 28:	learn: 0.0055964	total: 180ms	remaining: 131ms
# 29:	learn: 0.0053986	total: 188ms	remaining: 125ms
# 30:	learn: 0.0050502	total: 196ms	remaining: 120ms
# 31:	learn: 0.0047930	total: 204ms	remaining: 115ms
# 32:	learn: 0.0047424	total: 209ms	remaining: 108ms
# 33:	learn: 0.0046807	total: 216ms	remaining: 102ms
# 34:	learn: 0.0046121	total: 222ms	remaining: 95.3ms
# 35:	learn: 0.0044232	total: 228ms	remaining: 88.8ms
# 36:	learn: 0.0043232	total: 235ms	remaining: 82.5ms
# 37:	learn: 0.0041895	total: 241ms	remaining: 76.1ms
# 38:	learn: 0.0041649	total: 247ms	remaining: 69.8ms
# 39:	learn: 0.0039980	total: 253ms	remaining: 63.4ms
# 40:	learn: 0.0039285	total: 260ms	remaining: 57ms
# 41:	learn: 0.0039013	total: 266ms	remaining: 50.7ms
# 42:	learn: 0.0038590	total: 272ms	remaining: 44.3ms
# 43:	learn: 0.0037767	total: 279ms	remaining: 38ms
# 44:	learn: 0.0036766	total: 286ms	remaining: 31.8ms
# 45:	learn: 0.0035112	total: 292ms	remaining: 25.4ms
# 46:	learn: 0.0034686	total: 302ms	remaining: 19.2ms
# 47:	learn: 0.0033665	total: 307ms	remaining: 12.8ms
# 48:	learn: 0.0033453	total: 316ms	remaining: 6.45ms
# 49:	learn: 0.0032526	total: 322ms	remaining: 0us
#
#  Model Trained
#
# Target on train data ['0' '0' '0' ... '0' '1' '0']
#
# accuracy_score on train dataset : 0.9995706311721769
#
# Target on test data ['0' '0' '0' ... '0' '0' '0']
#
# accuracy_score on test dataset : 0.9946577629382304

# %%
#grab all features except for the target variable
X = train_scaled.iloc[:,:-1]
y = train_scaled[['label']]

#determine test_size for splitting the data
test_size = 0.3

#split data with random seed so we can replicate the results
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

# %%
#initialize the model
model = CatBoostClassifier(iterations=50)

# fit the model with the training data
model.fit(X_train, y_train, plot=False)
print('\n Scaled Model Trained')

# predict the target on the train dataset
y_pred_train = model.predict(X_train)
print(f'\nTarget on scaled train data {y_pred_train}') 

# Accuracy Score on train dataset
accuracy_train = accuracy_score(y_train, y_pred_train)
print(f'\naccuracy_score on scaled train dataset : {accuracy_train}')

# predict the target on the test dataset
y_pred_test = model.predict(X_test)
print(f'\nTarget on scaled test data {predict}') 

# Accuracy Score on test dataset
accuracy_test = accuracy_score(y_test,y_pred_test)
print(f'\naccuracy_score on scaled test dataset : {accuracy_test}')
# Out:
# Learning rate set to 0.495485
# 0:	learn: 0.0537017	total: 6.21ms	remaining: 304ms
# 1:	learn: 0.0223116	total: 12.5ms	remaining: 299ms
# 2:	learn: 0.0175498	total: 18.6ms	remaining: 292ms
# 3:	learn: 0.0173250	total: 24.6ms	remaining: 283ms
# 4:	learn: 0.0160093	total: 30.9ms	remaining: 278ms
# 5:	learn: 0.0159515	total: 36.8ms	remaining: 270ms
# 6:	learn: 0.0151107	total: 43.1ms	remaining: 265ms
# 7:	learn: 0.0146488	total: 49.2ms	remaining: 258ms
# 8:	learn: 0.0135428	total: 55.9ms	remaining: 254ms
# 9:	learn: 0.0120659	total: 64.6ms	remaining: 258ms
# 10:	learn: 0.0119140	total: 72.1ms	remaining: 256ms
# 11:	learn: 0.0111640	total: 79.5ms	remaining: 252ms
# 12:	learn: 0.0107415	total: 86.5ms	remaining: 246ms
# 13:	learn: 0.0107153	total: 93.3ms	remaining: 240ms
# 14:	learn: 0.0102324	total: 101ms	remaining: 235ms
# 15:	learn: 0.0092909	total: 109ms	remaining: 231ms
# 16:	learn: 0.0092185	total: 117ms	remaining: 226ms
# 17:	learn: 0.0088610	total: 125ms	remaining: 223ms
# 18:	learn: 0.0085341	total: 133ms	remaining: 217ms
# 19:	learn: 0.0079577	total: 143ms	remaining: 214ms
# 20:	learn: 0.0078333	total: 151ms	remaining: 208ms
# 21:	learn: 0.0073651	total: 158ms	remaining: 202ms
# 22:	learn: 0.0068370	total: 165ms	remaining: 194ms
# 23:	learn: 0.0064145	total: 174ms	remaining: 189ms
# 24:	learn: 0.0061995	total: 183ms	remaining: 183ms
# 25:	learn: 0.0061211	total: 190ms	remaining: 175ms
# 26:	learn: 0.0059200	total: 198ms	remaining: 168ms
# 27:	learn: 0.0056860	total: 205ms	remaining: 161ms
# 28:	learn: 0.0055964	total: 213ms	remaining: 154ms
# 29:	learn: 0.0053986	total: 220ms	remaining: 147ms
# 30:	learn: 0.0050502	total: 226ms	remaining: 139ms
# 31:	learn: 0.0047930	total: 232ms	remaining: 131ms
# 32:	learn: 0.0047424	total: 238ms	remaining: 123ms
# 33:	learn: 0.0046807	total: 244ms	remaining: 115ms
# 34:	learn: 0.0046121	total: 250ms	remaining: 107ms
# 35:	learn: 0.0044232	total: 256ms	remaining: 99.4ms
# 36:	learn: 0.0043232	total: 261ms	remaining: 91.8ms
# 37:	learn: 0.0041895	total: 267ms	remaining: 84.4ms
# 38:	learn: 0.0041649	total: 273ms	remaining: 77ms
# 39:	learn: 0.0039980	total: 279ms	remaining: 69.8ms
# 40:	learn: 0.0039285	total: 285ms	remaining: 62.6ms
# 41:	learn: 0.0039013	total: 291ms	remaining: 55.4ms
# 42:	learn: 0.0038590	total: 297ms	remaining: 48.4ms
# 43:	learn: 0.0037767	total: 303ms	remaining: 41.4ms
# 44:	learn: 0.0036766	total: 309ms	remaining: 34.4ms
# 45:	learn: 0.0035112	total: 315ms	remaining: 27.4ms
# 46:	learn: 0.0034686	total: 321ms	remaining: 20.5ms
# 47:	learn: 0.0033665	total: 327ms	remaining: 13.6ms
# 48:	learn: 0.0033453	total: 333ms	remaining: 6.79ms
# 49:	learn: 0.0032526	total: 339ms	remaining: 0us
#
#  Scaled Model Trained
#
# Target on scaled train data ['0' '0' '0' ... '0' '1' '0']
#
# accuracy_score on scaled train dataset : 0.9995706311721769
#
# Target on scaled test data ['0' '0' '0' ... '0' '0' '0']
#
# accuracy_score on scaled test dataset : 0.9946577629382304

# %%
#grab all features except for the target variable
X = train_log.iloc[:,:-1]
y = train_log[['label']]

#determine test_size for splitting the data
test_size = 0.3

#split data with random seed so we can replicate the results
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

# %%
#initialize the model
model = CatBoostClassifier(iterations=50)

# fit the model with the training data
model.fit(X_train, y_train, plot=False)
print('\n Log Model Trained')

# predict the target on the train dataset
y_pred_train = model.predict(X_train)
print(f'\nTarget on log train data {y_pred_train}') 

# Accuracy Score on train dataset
accuracy_train = accuracy_score(y_train, y_pred_train)
print(f'\naccuracy_score on log train dataset : {accuracy_train}')

# predict the target on the test dataset
y_pred_test = model.predict(X_test)
print(f'\nTarget on log test data {predict}') 

# Accuracy Score on test dataset
accuracy_test = accuracy_score(y_test,y_pred_test)
print(f'\naccuracy_score on log test dataset : {accuracy_test}')
# Out:
# Learning rate set to 0.495485
# 0:	learn: 0.0537017	total: 6.21ms	remaining: 305ms
# 1:	learn: 0.0223116	total: 12.6ms	remaining: 303ms
# 2:	learn: 0.0175498	total: 18.5ms	remaining: 290ms
# 3:	learn: 0.0173250	total: 24.1ms	remaining: 278ms
# 4:	learn: 0.0160093	total: 30ms	remaining: 270ms
# 5:	learn: 0.0159515	total: 35.6ms	remaining: 261ms
# 6:	learn: 0.0151107	total: 41.7ms	remaining: 256ms
# 7:	learn: 0.0146488	total: 47.7ms	remaining: 251ms
# 8:	learn: 0.0135428	total: 53.8ms	remaining: 245ms
# 9:	learn: 0.0120659	total: 60.3ms	remaining: 241ms
# 10:	learn: 0.0119140	total: 65.9ms	remaining: 234ms
# 11:	learn: 0.0111640	total: 72.3ms	remaining: 229ms
# 12:	learn: 0.0107415	total: 78ms	remaining: 222ms
# 13:	learn: 0.0107153	total: 83.9ms	remaining: 216ms
# 14:	learn: 0.0102324	total: 90.1ms	remaining: 210ms
# 15:	learn: 0.0092909	total: 96.2ms	remaining: 204ms
# 16:	learn: 0.0092185	total: 102ms	remaining: 197ms
# 17:	learn: 0.0088610	total: 108ms	remaining: 191ms
# 18:	learn: 0.0085341	total: 113ms	remaining: 185ms
# 19:	learn: 0.0079577	total: 119ms	remaining: 179ms
# 20:	learn: 0.0078333	total: 125ms	remaining: 173ms
# 21:	learn: 0.0073651	total: 131ms	remaining: 167ms
# 22:	learn: 0.0068370	total: 137ms	remaining: 161ms
# 23:	learn: 0.0064145	total: 143ms	remaining: 155ms
# 24:	learn: 0.0061995	total: 149ms	remaining: 149ms
# 25:	learn: 0.0061211	total: 155ms	remaining: 143ms
# 26:	learn: 0.0059200	total: 160ms	remaining: 136ms
# 27:	learn: 0.0056860	total: 166ms	remaining: 131ms
# 28:	learn: 0.0055964	total: 172ms	remaining: 125ms
# 29:	learn: 0.0053986	total: 180ms	remaining: 120ms
# 30:	learn: 0.0050502	total: 188ms	remaining: 115ms
# 31:	learn: 0.0047930	total: 195ms	remaining: 109ms
# 32:	learn: 0.0047424	total: 201ms	remaining: 104ms
# 33:	learn: 0.0046807	total: 207ms	remaining: 97.5ms
# 34:	learn: 0.0046121	total: 213ms	remaining: 91.3ms
# 35:	learn: 0.0044232	total: 219ms	remaining: 85.1ms
# 36:	learn: 0.0043232	total: 225ms	remaining: 78.9ms
# 37:	learn: 0.0041895	total: 231ms	remaining: 72.8ms
# 38:	learn: 0.0041649	total: 236ms	remaining: 66.7ms
# 39:	learn: 0.0039980	total: 242ms	remaining: 60.6ms
# 40:	learn: 0.0039285	total: 248ms	remaining: 54.5ms
# 41:	learn: 0.0039013	total: 254ms	remaining: 48.5ms
# 42:	learn: 0.0038590	total: 260ms	remaining: 42.4ms
# 43:	learn: 0.0037767	total: 266ms	remaining: 36.3ms
# 44:	learn: 0.0036766	total: 272ms	remaining: 30.2ms
# 45:	learn: 0.0035112	total: 278ms	remaining: 24.2ms
# 46:	learn: 0.0034686	total: 284ms	remaining: 18.1ms
# 47:	learn: 0.0033665	total: 290ms	remaining: 12.1ms
# 48:	learn: 0.0033453	total: 296ms	remaining: 6.04ms
# 49:	learn: 0.0032526	total: 302ms	remaining: 0us
#
#  Log Model Trained
#
# Target on log train data ['0' '0' '0' ... '0' '1' '0']
#
# accuracy_score on log train dataset : 0.9995706311721769
#
# Target on log test data ['0' '0' '0' ... '0' '0' '0']
#
# accuracy_score on log test dataset : 0.9946577629382304

# %% [markdown]
# ### RANDOM FOREST

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier

# %%
#Fit a Random Forest model
clf = RandomForestClassifier(n_estimators=100, max_features="auto",random_state=0)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-3f44fcc95c0b> in <module>
#       1 #Fit a Random Forest model
#       2 clf = RandomForestClassifier(n_estimators=100, max_features="auto",random_state=0)
# ----> 3 clf.fit(X_train, y_train)
#       4 y_pred = clf.predict(X_test)
#       5 accuracy_score(y_test, y_pred)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     324         if issparse(y):
#     325             raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 326         X, y = self._validate_data(
#     327             X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     328         )
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     570                 y = check_array(y, **check_y_params)
#     571             else:
# --> 572                 X, y = check_X_y(X, y, **check_params)
#     573             out = X, y
#     574
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     954         raise ValueError("y cannot be None")
#     955
# --> 956     X = check_array(
#     957         X,
#     958         accept_sparse=accept_sparse,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     790
#     791         if force_all_finite:
# --> 792             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     793
#     794     if ensure_min_samples > 0:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     112         ):
#     113             type_err = "infinity" if allow_nan else "NaN, infinity"
# --> 114             raise ValueError(
#     115                 msg_err.format(
#     116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
#Fit a Decision Tree model as comparison
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
OUTPUT: 0.756
    
#Fit a AdaBoost model, " compared to "Decision Tree model, accuracy go up by 10%
clf = AdaBoostClassifier(n_estimators=100)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
OUTPUT:0.833
    
#Fit a Gradient Boosting model, " compared to "Decision Tree model, accuracy go up by 10%
clf = GradientBoostingClassifier(n_estimators=100)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
OUTPUT:0.834
Note: Parameter - n_estimators stands for how many tree we want to grow
